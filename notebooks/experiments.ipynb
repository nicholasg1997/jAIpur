# %%
from sb3_plus import MultiOutputPPO
from stable_baselines3.common.evaluation import evaluate_policy
import gymnasium as gym

# Create environment
env = gym.make('Moving-v0', render_mode='rgb_array')

# Instantiate the agent
model = MultiOutputPPO(
    policy='MultiOutputPolicy',
    env=env,
    verbose=1,
    policy_kwargs=dict(
        net_arch=dict(pi=[252] * 4, vf=[252] * 4)
    )
)

# Train the agent and display a progress bar
model.learn(
    total_timesteps=int(2e5),
    progress_bar=True
)

# Save the agent
model.save("ppo_moving")
del model  # delete trained model to demonstrate loading

# Load the trained agent
model = MultiOutputPPO.load("ppo_moving", env=env)

# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean Reward {mean_reward} | Std Reward {std_reward}')

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render('human')
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[1], line 6
#       3 import gymnasium as gym
#       5 # Create environment
# ----> 6 env = gym.make('Moving-v0', render_mode='rgb_array')
#       8 # Instantiate the agent
#       9 model = MultiOutputPPO(
#      10     policy='MultiOutputPolicy',
#      11     env=env,
#    (...)
#      15     )
#      16 )
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/gymnasium/envs/registration.py:687, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     684     assert isinstance(id, str)
#     686     # The environment name can include an unloaded module in "module:env_name" style
# --> 687     env_spec = _find_spec(id)
#     689 assert isinstance(env_spec, EnvSpec)
#     691 # Update the env spec kwargs with the `make` kwargs
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/gymnasium/envs/registration.py:531, in _find_spec(env_id)
#     525     logger.warn(
#     526         f"Using the latest versioned environment `{new_env_id}` "
#     527         f"instead of the unversioned environment `{env_name}`."
#     528     )
#     530 if env_spec is None:
# --> 531     _check_version_exists(ns, name, version)
#     532     raise error.Error(
#     533         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     534     )
#     536 return env_spec
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/gymnasium/envs/registration.py:397, in _check_version_exists(ns, name, version)
#     394 if get_env_id(ns, name, version) in registry:
#     395     return
# --> 397 _check_name_exists(ns, name)
#     398 if version is None:
#     399     return
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/gymnasium/envs/registration.py:374, in _check_name_exists(ns, name)
#     371 namespace_msg = f" in namespace {ns}" if ns else ""
#     372 suggestion_msg = f" Did you mean: `{suggestion[0]}`?" if suggestion else ""
# --> 374 raise error.NameNotFound(
#     375     f"Environment `{name}` doesn't exist{namespace_msg}.{suggestion_msg}"
#     376 )
#
# NameNotFound: Environment `Moving` doesn't exist.

# %%
import multiprocessing as mp
mp.set_start_method('spawn', force=True)

from stable_baselines3.common.vec_env import SubprocVecEnv
from sb3_plus import MultiOutputPPO
from jaipur_rl.envs.jaipur_env import JaipurEnv

env = SubprocVecEnv([lambda: JaipurEnv(seed=42)])
model = MultiOutputPPO("MultiOutputPolicy", env)
print("Success")
# Out:
# Success

# %%
from jaipur_rl.envs.jaipur_env import JaipurEnv
model = MultiOutputPPO("MultiOutputPolicy", JaipurEnv(seed=42))
model.learn(
    total_timesteps=10000,
    progress_bar=True,

)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from jaipur_rl.envs.jaipur_env import JaipurEnv
#       2 model = MultiOutputPPO("MultiOutputPolicy", JaipurEnv(seed=42))
# ----> 3 model.learn(
#       4     total_timesteps=10000,
#       5     progress_bar=True,
#       6
#       7 )
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/sb3_plus/mimo/ppo.py:323, in MultiOutputPPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     314 def learn(
#     315         self: SelfMultiOutputPPO,
#     316         total_timesteps: int,
#    (...)
#     321         progress_bar: bool = False,
#     322 ) -> SelfMultiOutputPPO:
# --> 323     super().learn(
#     324         total_timesteps=total_timesteps,
#     325         callback=callback,
#     326         log_interval=log_interval,
#     327         tb_log_name=tb_log_name,
#     328         reset_num_timesteps=reset_num_timesteps,
#     329         progress_bar=progress_bar,
#     330     )
#     331     return self
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:310, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfOnPolicyAlgorithm,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfOnPolicyAlgorithm:
#     308     iteration = 0
# --> 310     total_timesteps, callback = self._setup_learn(
#     311         total_timesteps,
#     312         callback,
#     313         reset_num_timesteps,
#     314         tb_log_name,
#     315         progress_bar,
#     316     )
#     318     callback.on_training_start(locals(), globals())
#     320     assert self.env is not None
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:423, in BaseAlgorithm._setup_learn(self, total_timesteps, callback, reset_num_timesteps, tb_log_name, progress_bar)
#     421 if reset_num_timesteps or self._last_obs is None:
#     422     assert self.env is not None
# --> 423     self._last_obs = self.env.reset()  # type: ignore[assignment]
#     424     self._last_episode_starts = np.ones((self.env.num_envs,), dtype=bool)
#     425     # Retrieve unnormalized observation for saving into the buffer
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:78, in DummyVecEnv.reset(self)
#      76     maybe_options = {"options": self._options[env_idx]} if self._options[env_idx] else {}
#      77     obs, self.reset_infos[env_idx] = self.envs[env_idx].reset(seed=self._seeds[env_idx], **maybe_options)
# ---> 78     self._save_obs(env_idx, obs)
#      79 # Seeds and options are only used once
#      80 self._reset_seeds()
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:110, in DummyVecEnv._save_obs(self, env_idx, obs)
#     108     self.buf_obs[key][env_idx] = obs
#     109 else:
# --> 110     self.buf_obs[key][env_idx] = obs[key]
#
# ValueError: could not broadcast input array from shape (6,) into shape (5,)
