# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from jaipur_rl.envs.jaipur_env import JaipurEnv
from sb3_plus import MultiOutputPPO

env = JaipurEnv(seed=42)
model = MultiOutputPPO.load("/Users/nickgault/PycharmProjects/jAIpur/jaipur_rl/training/models/Jaipur_25.0M_scheduler_2025-06-15_14-41-20.zip", env=None)
trained_agent = model

p1_scores = []
p2_scores = []
p1_wins = 0
p2_wins = 0
games = 100
games_finished = 0

for i in range(games):
    obs, _ = env.reset()
    print(f"Game {i+1} Start")
    for j in range(200):
        action_batch, _ = trained_agent.predict(obs, deterministic=False)

        obs, reward, done, truncated, info = env.step(action_batch)

        if done or truncated:
            games_finished += 1
            p1_score = info.get('P1_Final_Score')
            p1_scores.append(p1_score)
            p2_score = info.get('P2_Final_Score')
            p2_scores.append(p2_score)
            if info['winner'] == 'P1':
                p1_wins += 1
            elif info['winner'] == 'P2':
                p2_wins += 1

            break

print(f"Player 1 Score: {sum(p1_scores)/games}, Player 2 Score: {sum(p2_scores)/games}")
print(f"Player 1 Wins: {p1_wins}, Player 2 Wins: {p2_wins}")
print(f"Games Finished: {games_finished}/{games}")
# Out:
# Game 1 Start
# Game 2 Start
# Game 3 Start
# Game 4 Start
# Game 5 Start
# Game 6 Start
# Game 7 Start
# Game 8 Start
# Game 9 Start
# Game 10 Start
# Game 11 Start
# Game 12 Start
# Game 13 Start
# Game 14 Start
# Game 15 Start
# Game 16 Start
# Game 17 Start
# Game 18 Start
# Game 19 Start
# Game 20 Start
# Game 21 Start
# Game 22 Start
# Game 23 Start
# Game 24 Start
# Game 25 Start
# Game 26 Start
# Game 27 Start
# Game 28 Start
# Game 29 Start
# Game 30 Start
# Game 31 Start
# Game 32 Start
# Game 33 Start
# Game 34 Start
# Game 35 Start
# Game 36 Start
# Game 37 Start
# Game 38 Start
# Game 39 Start
# Game 40 Start
# Game 41 Start
# Game 42 Start
# Game 43 Start
# Game 44 Start
# Game 45 Start
# Game 46 Start
# Game 47 Start
# Game 48 Start
# Game 49 Start
# Game 50 Start
# Game 51 Start
# Game 52 Start
# Game 53 Start
# Game 54 Start
# Game 55 Start
# Game 56 Start
# Game 57 Start
# Game 58 Start
# Game 59 Start
# Game 60 Start
# Game 61 Start
# Game 62 Start
# Game 63 Start
# Game 64 Start
# Game 65 Start
# Game 66 Start
# Game 67 Start
# Game 68 Start
# Game 69 Start
# Game 70 Start
# Game 71 Start
# Game 72 Start
# Game 73 Start
# Game 74 Start
# Game 75 Start
# Game 76 Start
# Game 77 Start
# Game 78 Start
# Game 79 Start
# Game 80 Start
# Game 81 Start
# Game 82 Start
# Game 83 Start
# Game 84 Start
# Game 85 Start
# Game 86 Start
# Game 87 Start
# Game 88 Start
# Game 89 Start
# Game 90 Start
# Game 91 Start
# Game 92 Start
# Game 93 Start
# Game 94 Start
# Game 95 Start
# Game 96 Start
# Game 97 Start
# Game 98 Start
# Game 99 Start
# Game 100 Start
# Player 1 Score: 64.14, Player 2 Score: 49.53
# Player 1 Wins: 81, Player 2 Wins: 19
# Games Finished: 100/100

# %%
# Your existing setup is correct
model_env = DummyVecEnv([lambda: JaipurEnv(seed=42)])
model = MultiOutputPPO.load("/Users/nickgault/PycharmProjects/jAIpur/jaipur_rl/training/models/Jaipur_25.0M_scheduler_2025-06-15_14-41-20.zip", env=model_env)
env = model.get_env() # env is a DummyVecEnv
trained_agent = model

# ... lists for scores ...

for i in range (50):
    obs = env.reset()
    print(f"Game {i+1} Start")
    for i in range(200):
        # 1. Predict and get the BATCHED action dictionary
        action_batch, _ = trained_agent.predict(obs, deterministic=True)
        print()

        # 2. THE FIX: Convert the batched action to a single action dictionary
        #    by taking the first element ([0]) from each numpy array.
        single_action = {key: value[0] for key, value in action_batch.items()}

        # 3. Step the environment using the correctly formatted single action.
        #    The VecEnv needs a list of actions, so we wrap our single action in a list.
        obs, reward, done, truncated, info = env.step([single_action])

        if done[0] or truncated[0]: # Check the first element for done/truncated status
            print("Game Over")
            # For VecEnvs, info is an array of dicts. We need the one for our env.
            final_info = info[0]
            p1_score = final_info.get('P1_Final_Score')
            p1_scores.append(p1_score)
            p2_score = final_info.get('P2_Final_Score')
            p2_scores.append(p2_score)
            break

print(f"Player 1 Score: {sum(p1_scores)/50}, Player 2 Score: {sum(p2_scores)/50}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 3
#       1 # Your existing setup is correct
#       2 model_env = DummyVecEnv([lambda: JaipurEnv(seed=42)])
# ----> 3 model = MultiOutputPPO.load("jAIpur/jaipur_rl/training/models/Jaipur_25.0M_scheduler_2025-06-15_14-41-20.zip", env=model_env)
#       4 env = model.get_env() # env is a DummyVecEnv
#       5 trained_agent = model
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:680, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     677     print("== CURRENT SYSTEM INFO ==")
#     678     get_system_info()
# --> 680 data, params, pytorch_variables = load_from_zip_file(
#     681     path,
#     682     device=device,
#     683     custom_objects=custom_objects,
#     684     print_system_info=print_system_info,
#     685 )
#     687 assert data is not None, "No data found in the saved file"
#     688 assert params is not None, "No params found in the saved file"
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:403, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     376 def load_from_zip_file(
#     377     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     378     load_data: bool = True,
#    (...)
#     382     print_system_info: bool = False,
#     383 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     384     """
#     385     Load model data from a .zip archive
#     386
#    (...)
#     401         and dict of pytorch variables
#     402     """
# --> 403     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     405     # set device to cpu if cuda is not available
#     406     device = get_device(device=device)
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:240, in open_path_str(path, mode, verbose, suffix)
#     225 @open_path.register(str)
#     226 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     227     """
#     228     Open a path given by a string. If writing to the path, the function ensures
#     229     that the path exists.
#    (...)
#     238     :return:
#     239     """
# --> 240     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:291, in open_path_pathlib(path, mode, verbose, suffix)
#     285         path.parent.mkdir(exist_ok=True, parents=True)
#     287 # if opening was successful uses the open_path() function
#     288 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     289 #   with corrections
#     290 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 291 return open_path_pathlib(path, mode, verbose, suffix)
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:272, in open_path_pathlib(path, mode, verbose, suffix)
#     270             path, suffix = newpath, None
#     271         else:
# --> 272             raise error
#     273 else:
#     274     try:
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262 if mode == "r":
#     263     try:
# --> 264         return open_path(path.open("rb"), mode, verbose, suffix)
#     265     except FileNotFoundError as error:
#     266         if suffix is not None and suffix != "":
#
# File ~/opt/miniconda3/envs/jAIpur/lib/python3.10/pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jAIpur/jaipur_rl/training/models/Jaipur_25.0M_scheduler_2025-06-15_14-41-20.zip.zip'

# %%
import multiprocessing as mp
mp.set_start_method('spawn', force=True)

from stable_baselines3.common.vec_env import SubprocVecEnv
from sb3_plus import MultiOutputPPO
from jaipur_rl.envs.jaipur_env import JaipurEnv

env = SubprocVecEnv([lambda: JaipurEnv(seed=42)])
model = MultiOutputPPO("MultiOutputPolicy", env)
print("Success")

# %%
from jaipur_rl.envs.jaipur_env import JaipurEnv
model = MultiOutputPPO("MultiOutputPolicy", JaipurEnv(seed=42))
model.learn(
    total_timesteps=10000,
    progress_bar=True,

)
